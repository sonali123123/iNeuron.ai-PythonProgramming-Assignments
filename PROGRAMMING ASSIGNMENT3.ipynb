# %%
#Q1. Write a python program to check if a number is positive ,negative or zero?

# %%
num=float(input("Enter the number: "))

if num>0:
    print("positive number")
elif num<0:
    print("negative")
    
elif num==0:
    print("zero")
# Out:
# Enter the number: 0
# zero

# %%
#Q2.  Write a python program to check if a number is Odd or Even?

# %%
num=int(input("Enter the number: "))
if (num%2)==0:
    print("even number")
elif (num%2)==1:
    print("odd number")
# Out:
# Enter the number: 4
# even number

# %%
#Q3. Write a python program to check Leap Year?

# %%
year=int(input("Enter the year: "))
if (year%4==0 and year%100 !=0) or (year%400==0):
    print("Given year is leap year")
else:
    print("given year is not leap year")
# Out:
# Enter the year: 2012
# Given year is leap year

# %%
#Q4. Write  a python program to check Prime Number?

# %%
num=int(input("enter the number:"))
lim=int(num/2)+1
for i in range(2,lim):
    rem=num%i
    if rem==0:
        print(num,"is not prime")
        break
else:
    print(num,"is prime")
# Out:
# enter the number:5
# 5 is prime

# %%
#Q5. Write a python program to print all prime numbers in an interval 1-10000

# %%
for num in range(1,10000):
    for i in range(2,num):
        if num%i==0:
            j=num/i
            print("Found a factor(",i,")for ",num)
            break
    else:
        print(num,"is  prime")
# Out:
# 1 is  prime
# 2 is  prime
# 3 is  prime
# Found a factor( 2 )for  4
# 5 is  prime
# Found a factor( 2 )for  6
# 7 is  prime
# Found a factor( 2 )for  8
# Found a factor( 3 )for  9
# Found a factor( 2 )for  10
# 11 is  prime
# Found a factor( 2 )for  12
# 13 is  prime
# Found a factor( 2 )for  14
# Found a factor( 3 )for  15
# Found a factor( 2 )for  16
# 17 is  prime
# Found a factor( 2 )for  18
# 19 is  prime
# Found a factor( 2 )for  20
# Found a factor( 3 )for  21
# Found a factor( 2 )for  22
# 23 is  prime
# Found a factor( 2 )for  24
# Found a factor( 5 )for  25
# Found a factor( 2 )for  26
# Found a factor( 3 )for  27
# Found a factor( 2 )for  28
# 29 is  prime
# Found a factor( 2 )for  30
# 31 is  prime
# Found a factor( 2 )for  32
# Found a factor( 3 )for  33
# Found a factor( 2 )for  34
# Found a factor( 5 )for  35
# Found a factor( 2 )for  36
# 37 is  prime
# Found a factor( 2 )for  38
# Found a factor( 3 )for  39
# Found a factor( 2 )for  40
# 41 is  prime
# Found a factor( 2 )for  42
# 43 is  prime
# Found a factor( 2 )for  44
# Found a factor( 3 )for  45
# Found a factor( 2 )for  46
# 47 is  prime
# Found a factor( 2 )for  48
# Found a factor( 7 )for  49
# Found a factor( 2 )for  50
# Found a factor( 3 )for  51
# Found a factor( 2 )for  52
# 53 is  prime
# Found a factor( 2 )for  54
# Found a factor( 5 )for  55
# Found a factor( 2 )for  56
# Found a factor( 3 )for  57
# Found a factor( 2 )for  58
# 59 is  prime
# Found a factor( 2 )for  60
# 61 is  prime
# Found a factor( 2 )for  62
# Found a factor( 3 )for  63
# Found a factor( 2 )for  64
# Found a factor( 5 )for  65
# Found a factor( 2 )for  66
# 67 is  prime
# Found a factor( 2 )for  68
# Found a factor( 3 )for  69
# Found a factor( 2 )for  70
# 71 is  prime
# Found a factor( 2 )for  72
# 73 is  prime
# Found a factor( 2 )for  74
# Found a factor( 3 )for  75
# Found a factor( 2 )for  76
# Found a factor( 7 )for  77
# Found a factor( 2 )for  78
# 79 is  prime
# Found a factor( 2 )for  80
# Found a factor( 3 )for  81
# Found a factor( 2 )for  82
# 83 is  prime
# Found a factor( 2 )for  84
# Found a factor( 5 )for  85
# Found a factor( 2 )for  86
# Found a factor( 3 )for  87
# Found a factor( 2 )for  88
# 89 is  prime
# Found a factor( 2 )for  90
# Found a factor( 7 )for  91
# Found a factor( 2 )for  92
# Found a factor( 3 )for  93
# Found a factor( 2 )for  94
# Found a factor( 5 )for  95
# Found a factor( 2 )for  96
# 97 is  prime
# Found a factor( 2 )for  98
# Found a factor( 3 )for  99
# Found a factor( 2 )for  100
# 101 is  prime
# Found a factor( 2 )for  102
# 103 is  prime
# Found a factor( 2 )for  104
# Found a factor( 3 )for  105
# Found a factor( 2 )for  106
# 107 is  prime
# Found a factor( 2 )for  108
# 109 is  prime
# Found a factor( 2 )for  110
# Found a factor( 3 )for  111
# Found a factor( 2 )for  112
# 113 is  prime
# Found a factor( 2 )for  114
# Found a factor( 5 )for  115
# Found a factor( 2 )for  116
# Found a factor( 3 )for  117
# Found a factor( 2 )for  118
# Found a factor( 7 )for  119
# Found a factor( 2 )for  120
# Found a factor( 11 )for  121
# Found a factor( 2 )for  122
# Found a factor( 3 )for  123
# Found a factor( 2 )for  124
# Found a factor( 5 )for  125
# Found a factor( 2 )for  126
# 127 is  prime
# Found a factor( 2 )for  128
# Found a factor( 3 )for  129
# Found a factor( 2 )for  130
# 131 is  prime
# Found a factor( 2 )for  132
# Found a factor( 7 )for  133
# Found a factor( 2 )for  134
# Found a factor( 3 )for  135
# Found a factor( 2 )for  136
# 137 is  prime
# Found a factor( 2 )for  138
# 139 is  prime
# Found a factor( 2 )for  140
# Found a factor( 3 )for  141
# Found a factor( 2 )for  142
# Found a factor( 11 )for  143
# Found a factor( 2 )for  144
# Found a factor( 5 )for  145
# Found a factor( 2 )for  146
# Found a factor( 3 )for  147
# Found a factor( 2 )for  148
# 149 is  prime
# Found a factor( 2 )for  150
# 151 is  prime
# Found a factor( 2 )for  152
# Found a factor( 3 )for  153
# Found a factor( 2 )for  154
# Found a factor( 5 )for  155
# Found a factor( 2 )for  156
# 157 is  prime
# Found a factor( 2 )for  158
# Found a factor( 3 )for  159
# Found a factor( 2 )for  160
# Found a factor( 7 )for  161
# Found a factor( 2 )for  162
# 163 is  prime
# Found a factor( 2 )for  164
# Found a factor( 3 )for  165
# Found a factor( 2 )for  166
# 167 is  prime
# Found a factor( 2 )for  168
# Found a factor( 13 )for  169
# Found a factor( 2 )for  170
# Found a factor( 3 )for  171
# Found a factor( 2 )for  172
# 173 is  prime
# Found a factor( 2 )for  174
# Found a factor( 5 )for  175
# Found a factor( 2 )for  176
# Found a factor( 3 )for  177
# Found a factor( 2 )for  178
# 179 is  prime
# Found a factor( 2 )for  180
# 181 is  prime
# Found a factor( 2 )for  182
# Found a factor( 3 )for  183
# Found a factor( 2 )for  184
# Found a factor( 5 )for  185
# Found a factor( 2 )for  186
# Found a factor( 11 )for  187
# Found a factor( 2 )for  188
# Found a factor( 3 )for  189
# Found a factor( 2 )for  190
# 191 is  prime
# Found a factor( 2 )for  192
# 193 is  prime
# Found a factor( 2 )for  194
# Found a factor( 3 )for  195
# Found a factor( 2 )for  196
# 197 is  prime
# Found a factor( 2 )for  198
# 199 is  prime
# Found a factor( 2 )for  200
# Found a factor( 3 )for  201
# Found a factor( 2 )for  202
# Found a factor( 7 )for  203
# Found a factor( 2 )for  204
# Found a factor( 5 )for  205
# Found a factor( 2 )for  206
# Found a factor( 3 )for  207
# Found a factor( 2 )for  208
# Found a factor( 11 )for  209
# Found a factor( 2 )for  210
# 211 is  prime
# Found a factor( 2 )for  212
# Found a factor( 3 )for  213
# Found a factor( 2 )for  214
# Found a factor( 5 )for  215
# Found a factor( 2 )for  216
# Found a factor( 7 )for  217
# Found a factor( 2 )for  218
# Found a factor( 3 )for  219
# Found a factor( 2 )for  220
# Found a factor( 13 )for  221
# Found a factor( 2 )for  222
# 223 is  prime
# Found a factor( 2 )for  224
# Found a factor( 3 )for  225
# Found a factor( 2 )for  226
# 227 is  prime
# Found a factor( 2 )for  228
# 229 is  prime
# Found a factor( 2 )for  230
# Found a factor( 3 )for  231
# Found a factor( 2 )for  232
# 233 is  prime
# Found a factor( 2 )for  234
# Found a factor( 5 )for  235
# Found a factor( 2 )for  236
# Found a factor( 3 )for  237
# Found a factor( 2 )for  238
# 239 is  prime
# Found a factor( 2 )for  240
# 241 is  prime
# Found a factor( 2 )for  242
# Found a factor( 3 )for  243
# Found a factor( 2 )for  244
# Found a factor( 5 )for  245
# Found a factor( 2 )for  246
# Found a factor( 13 )for  247
# Found a factor( 2 )for  248
# Found a factor( 3 )for  249
# Found a factor( 2 )for  250
# 251 is  prime
# Found a factor( 2 )for  252
# Found a factor( 11 )for  253
# Found a factor( 2 )for  254
# Found a factor( 3 )for  255
# Found a factor( 2 )for  256
# 257 is  prime
# Found a factor( 2 )for  258
# Found a factor( 7 )for  259
# Found a factor( 2 )for  260
# Found a factor( 3 )for  261
# Found a factor( 2 )for  262
# 263 is  prime
# Found a factor( 2 )for  264
# Found a factor( 5 )for  265
# Found a factor( 2 )for  266
# Found a factor( 3 )for  267
# Found a factor( 2 )for  268
# 269 is  prime
# Found a factor( 2 )for  270
# 271 is  prime
# Found a factor( 2 )for  272
# Found a factor( 3 )for  273
# Found a factor( 2 )for  274
# Found a factor( 5 )for  275
# Found a factor( 2 )for  276
# 277 is  prime
# Found a factor( 2 )for  278
# Found a factor( 3 )for  279
# Found a factor( 2 )for  280
# 281 is  prime
# Found a factor( 2 )for  282
# 283 is  prime
# Found a factor( 2 )for  284
# Found a factor( 3 )for  285
# Found a factor( 2 )for  286
# Found a factor( 7 )for  287
# Found a factor( 2 )for  288
# Found a factor( 17 )for  289
# Found a factor( 2 )for  290
# Found a factor( 3 )for  291
# Found a factor( 2 )for  292
# 293 is  prime
# Found a factor( 2 )for  294
# Found a factor( 5 )for  295
# Found a factor( 2 )for  296
# Found a factor( 3 )for  297
# Found a factor( 2 )for  298
# Found a factor( 13 )for  299
# Found a factor( 2 )for  300
# Found a factor( 7 )for  301
# Found a factor( 2 )for  302
# Found a factor( 3 )for  303
# Found a factor( 2 )for  304
# Found a factor( 5 )for  305
# Found a factor( 2 )for  306
# 307 is  prime
# Found a factor( 2 )for  308
# Found a factor( 3 )for  309
# Found a factor( 2 )for  310
# 311 is  prime
# Found a factor( 2 )for  312
# 313 is  prime
# Found a factor( 2 )for  314
# Found a factor( 3 )for  315
# Found a factor( 2 )for  316
# 317 is  prime
# Found a factor( 2 )for  318
# Found a factor( 11 )for  319
# Found a factor( 2 )for  320
# Found a factor( 3 )for  321
# Found a factor( 2 )for  322
# Found a factor( 17 )for  323
# Found a factor( 2 )for  324
# Found a factor( 5 )for  325
# Found a factor( 2 )for  326
# Found a factor( 3 )for  327
# Found a factor( 2 )for  328
# Found a factor( 7 )for  329
# Found a factor( 2 )for  330
# 331 is  prime
# Found a factor( 2 )for  332
# Found a factor( 3 )for  333
# Found a factor( 2 )for  334
# Found a factor( 5 )for  335
# Found a factor( 2 )for  336
# 337 is  prime
# Found a factor( 2 )for  338
# Found a factor( 3 )for  339
# Found a factor( 2 )for  340
# Found a factor( 11 )for  341
# Found a factor( 2 )for  342
# Found a factor( 7 )for  343
# Found a factor( 2 )for  344
# Found a factor( 3 )for  345
# Found a factor( 2 )for  346
# 347 is  prime
# Found a factor( 2 )for  348
# 349 is  prime
# Found a factor( 2 )for  350
# Found a factor( 3 )for  351
# Found a factor( 2 )for  352
# 353 is  prime
# Found a factor( 2 )for  354
# Found a factor( 5 )for  355
# Found a factor( 2 )for  356
# Found a factor( 3 )for  357
# Found a factor( 2 )for  358
# 359 is  prime
# Found a factor( 2 )for  360
# Found a factor( 19 )for  361
# Found a factor( 2 )for  362
# Found a factor( 3 )for  363
# Found a factor( 2 )for  364
# Found a factor( 5 )for  365
# Found a factor( 2 )for  366
# 367 is  prime
# Found a factor( 2 )for  368
# Found a factor( 3 )for  369
# Found a factor( 2 )for  370
# Found a factor( 7 )for  371
# Found a factor( 2 )for  372
# 373 is  prime
# Found a factor( 2 )for  374
# Found a factor( 3 )for  375
# Found a factor( 2 )for  376
# Found a factor( 13 )for  377
# Found a factor( 2 )for  378
# 379 is  prime
# Found a factor( 2 )for  380
# Found a factor( 3 )for  381
# Found a factor( 2 )for  382
# 383 is  prime
# Found a factor( 2 )for  384
# Found a factor( 5 )for  385
# Found a factor( 2 )for  386
# Found a factor( 3 )for  387
# Found a factor( 2 )for  388
# 389 is  prime
# Found a factor( 2 )for  390
# Found a factor( 17 )for  391
# Found a factor( 2 )for  392
# Found a factor( 3 )for  393
# Found a factor( 2 )for  394
# Found a factor( 5 )for  395
# Found a factor( 2 )for  396
# 397 is  prime
# Found a factor( 2 )for  398
# Found a factor( 3 )for  399
# Found a factor( 2 )for  400
# 401 is  prime
# Found a factor( 2 )for  402
# Found a factor( 13 )for  403
# Found a factor( 2 )for  404
# Found a factor( 3 )for  405
# Found a factor( 2 )for  406
# Found a factor( 11 )for  407
# Found a factor( 2 )for  408
# 409 is  prime
# Found a factor( 2 )for  410
# Found a factor( 3 )for  411
# Found a factor( 2 )for  412
# Found a factor( 7 )for  413
# Found a factor( 2 )for  414
# Found a factor( 5 )for  415
# Found a factor( 2 )for  416
# Found a factor( 3 )for  417
# Found a factor( 2 )for  418
# 419 is  prime
# Found a factor( 2 )for  420
# 421 is  prime
# Found a factor( 2 )for  422
# Found a factor( 3 )for  423
# Found a factor( 2 )for  424
# Found a factor( 5 )for  425
# Found a factor( 2 )for  426
# Found a factor( 7 )for  427
# Found a factor( 2 )for  428
# Found a factor( 3 )for  429
# Found a factor( 2 )for  430
# 431 is  prime
# Found a factor( 2 )for  432
# 433 is  prime
# Found a factor( 2 )for  434
# Found a factor( 3 )for  435
# Found a factor( 2 )for  436
# Found a factor( 19 )for  437
# Found a factor( 2 )for  438
# 439 is  prime
# Found a factor( 2 )for  440
# Found a factor( 3 )for  441
# Found a factor( 2 )for  442
# 443 is  prime
# Found a factor( 2 )for  444
# Found a factor( 5 )for  445
# Found a factor( 2 )for  446
# Found a factor( 3 )for  447
# Found a factor( 2 )for  448
# 449 is  prime
# Found a factor( 2 )for  450
# Found a factor( 11 )for  451
# Found a factor( 2 )for  452
# Found a factor( 3 )for  453
# Found a factor( 2 )for  454
# Found a factor( 5 )for  455
# Found a factor( 2 )for  456
# 457 is  prime
# Found a factor( 2 )for  458
# Found a factor( 3 )for  459
# Found a factor( 2 )for  460
# 461 is  prime
# Found a factor( 2 )for  462
# 463 is  prime
# Found a factor( 2 )for  464
# Found a factor( 3 )for  465
# Found a factor( 2 )for  466
# 467 is  prime
# Found a factor( 2 )for  468
# Found a factor( 7 )for  469
# Found a factor( 2 )for  470
# Found a factor( 3 )for  471
# Found a factor( 2 )for  472
# Found a factor( 11 )for  473
# Found a factor( 2 )for  474
# Found a factor( 5 )for  475
# Found a factor( 2 )for  476
# Found a factor( 3 )for  477
# Found a factor( 2 )for  478
# 479 is  prime
# Found a factor( 2 )for  480
# Found a factor( 13 )for  481
# Found a factor( 2 )for  482
# Found a factor( 3 )for  483
# Found a factor( 2 )for  484
# Found a factor( 5 )for  485
# Found a factor( 2 )for  486
# 487 is  prime
# Found a factor( 2 )for  488
# Found a factor( 3 )for  489
# Found a factor( 2 )for  490
# 491 is  prime
# Found a factor( 2 )for  492
# Found a factor( 17 )for  493
# Found a factor( 2 )for  494
# Found a factor( 3 )for  495
# Found a factor( 2 )for  496
# Found a factor( 7 )for  497
# Found a factor( 2 )for  498
# 499 is  prime
# Found a factor( 2 )for  500
# Found a factor( 3 )for  501
# Found a factor( 2 )for  502
# 503 is  prime
# Found a factor( 2 )for  504
# Found a factor( 5 )for  505
# Found a factor( 2 )for  506
# Found a factor( 3 )for  507
# Found a factor( 2 )for  508
# 509 is  prime
# Found a factor( 2 )for  510
# Found a factor( 7 )for  511
# Found a factor( 2 )for  512
# Found a factor( 3 )for  513
# Found a factor( 2 )for  514
# Found a factor( 5 )for  515
# Found a factor( 2 )for  516
# Found a factor( 11 )for  517
# Found a factor( 2 )for  518
# Found a factor( 3 )for  519
# Found a factor( 2 )for  520
# 521 is  prime
# Found a factor( 2 )for  522
# 523 is  prime
# Found a factor( 2 )for  524
# Found a factor( 3 )for  525
# Found a factor( 2 )for  526
# Found a factor( 17 )for  527
# Found a factor( 2 )for  528
# Found a factor( 23 )for  529
# Found a factor( 2 )for  530
# Found a factor( 3 )for  531
# Found a factor( 2 )for  532
# Found a factor( 13 )for  533
# Found a factor( 2 )for  534
# Found a factor( 5 )for  535
# Found a factor( 2 )for  536
# Found a factor( 3 )for  537
# Found a factor( 2 )for  538
# Found a factor( 7 )for  539
# Found a factor( 2 )for  540
# 541 is  prime
# Found a factor( 2 )for  542
# Found a factor( 3 )for  543
# Found a factor( 2 )for  544
# Found a factor( 5 )for  545
# Found a factor( 2 )for  546
# 547 is  prime
# Found a factor( 2 )for  548
# Found a factor( 3 )for  549
# Found a factor( 2 )for  550
# Found a factor( 19 )for  551
# Found a factor( 2 )for  552
# Found a factor( 7 )for  553
# Found a factor( 2 )for  554
# Found a factor( 3 )for  555
# Found a factor( 2 )for  556
# 557 is  prime
# Found a factor( 2 )for  558
# Found a factor( 13 )for  559
# Found a factor( 2 )for  560
# Found a factor( 3 )for  561
# Found a factor( 2 )for  562
# 563 is  prime
# Found a factor( 2 )for  564
# Found a factor( 5 )for  565
# Found a factor( 2 )for  566
# Found a factor( 3 )for  567
# Found a factor( 2 )for  568
# 569 is  prime
# Found a factor( 2 )for  570
# 571 is  prime
# Found a factor( 2 )for  572
# Found a factor( 3 )for  573
# Found a factor( 2 )for  574
# Found a factor( 5 )for  575
# Found a factor( 2 )for  576
# 577 is  prime
# Found a factor( 2 )for  578
# Found a factor( 3 )for  579
# Found a factor( 2 )for  580
# Found a factor( 7 )for  581
# Found a factor( 2 )for  582
# Found a factor( 11 )for  583
# Found a factor( 2 )for  584
# Found a factor( 3 )for  585
# Found a factor( 2 )for  586
# 587 is  prime
# Found a factor( 2 )for  588
# Found a factor( 19 )for  589
# Found a factor( 2 )for  590
# Found a factor( 3 )for  591
# Found a factor( 2 )for  592
# 593 is  prime
# Found a factor( 2 )for  594
# Found a factor( 5 )for  595
# Found a factor( 2 )for  596
# Found a factor( 3 )for  597
# Found a factor( 2 )for  598
# 599 is  prime
# Found a factor( 2 )for  600
# 601 is  prime
# Found a factor( 2 )for  602
# Found a factor( 3 )for  603
# Found a factor( 2 )for  604
# Found a factor( 5 )for  605
# Found a factor( 2 )for  606
# 607 is  prime
# Found a factor( 2 )for  608
# Found a factor( 3 )for  609
# Found a factor( 2 )for  610
# Found a factor( 13 )for  611
# Found a factor( 2 )for  612
# 613 is  prime
# Found a factor( 2 )for  614
# Found a factor( 3 )for  615
# Found a factor( 2 )for  616
# 617 is  prime
# Found a factor( 2 )for  618
# 619 is  prime
# Found a factor( 2 )for  620
# Found a factor( 3 )for  621
# Found a factor( 2 )for  622
# Found a factor( 7 )for  623
# Found a factor( 2 )for  624
# Found a factor( 5 )for  625
# Found a factor( 2 )for  626
# Found a factor( 3 )for  627
# Found a factor( 2 )for  628
# Found a factor( 17 )for  629
# Found a factor( 2 )for  630
# 631 is  prime
# Found a factor( 2 )for  632
# Found a factor( 3 )for  633
# Found a factor( 2 )for  634
# Found a factor( 5 )for  635
# Found a factor( 2 )for  636
# Found a factor( 7 )for  637
# Found a factor( 2 )for  638
# Found a factor( 3 )for  639
# Found a factor( 2 )for  640
# 641 is  prime
# Found a factor( 2 )for  642
# 643 is  prime
# Found a factor( 2 )for  644
# Found a factor( 3 )for  645
# Found a factor( 2 )for  646
# 647 is  prime
# Found a factor( 2 )for  648
# Found a factor( 11 )for  649
# Found a factor( 2 )for  650
# Found a factor( 3 )for  651
# Found a factor( 2 )for  652
# 653 is  prime
# Found a factor( 2 )for  654
# Found a factor( 5 )for  655
# Found a factor( 2 )for  656
# Found a factor( 3 )for  657
# Found a factor( 2 )for  658
# 659 is  prime
# Found a factor( 2 )for  660
# 661 is  prime
# Found a factor( 2 )for  662
# Found a factor( 3 )for  663
# Found a factor( 2 )for  664
# Found a factor( 5 )for  665
# Found a factor( 2 )for  666
# Found a factor( 23 )for  667
# Found a factor( 2 )for  668
# Found a factor( 3 )for  669
# Found a factor( 2 )for  670
# Found a factor( 11 )for  671
# Found a factor( 2 )for  672
# 673 is  prime
# Found a factor( 2 )for  674
# Found a factor( 3 )for  675
# Found a factor( 2 )for  676
# 677 is  prime
# Found a factor( 2 )for  678
# Found a factor( 7 )for  679
# Found a factor( 2 )for  680
# Found a factor( 3 )for  681
# Found a factor( 2 )for  682
# 683 is  prime
# Found a factor( 2 )for  684
# Found a factor( 5 )for  685
# Found a factor( 2 )for  686
# Found a factor( 3 )for  687
# Found a factor( 2 )for  688
# Found a factor( 13 )for  689
# Found a factor( 2 )for  690
# 691 is  prime
# Found a factor( 2 )for  692
# Found a factor( 3 )for  693
# Found a factor( 2 )for  694
# Found a factor( 5 )for  695
# Found a factor( 2 )for  696
# Found a factor( 17 )for  697
# Found a factor( 2 )for  698
# Found a factor( 3 )for  699
# Found a factor( 2 )for  700
# 701 is  prime
# Found a factor( 2 )for  702
# Found a factor( 19 )for  703
# Found a factor( 2 )for  704
# Found a factor( 3 )for  705
# Found a factor( 2 )for  706
# Found a factor( 7 )for  707
# Found a factor( 2 )for  708
# 709 is  prime
# Found a factor( 2 )for  710
# Found a factor( 3 )for  711
# Found a factor( 2 )for  712
# Found a factor( 23 )for  713
# Found a factor( 2 )for  714
# Found a factor( 5 )for  715
# Found a factor( 2 )for  716
# Found a factor( 3 )for  717
# Found a factor( 2 )for  718
# 719 is  prime
# Found a factor( 2 )for  720
# Found a factor( 7 )for  721
# Found a factor( 2 )for  722
# Found a factor( 3 )for  723
# Found a factor( 2 )for  724
# Found a factor( 5 )for  725
# Found a factor( 2 )for  726
# 727 is  prime
# Found a factor( 2 )for  728
# Found a factor( 3 )for  729
# Found a factor( 2 )for  730
# Found a factor( 17 )for  731
# Found a factor( 2 )for  732
# 733 is  prime
# Found a factor( 2 )for  734
# Found a factor( 3 )for  735
# Found a factor( 2 )for  736
# Found a factor( 11 )for  737
# Found a factor( 2 )for  738
# 739 is  prime
# Found a factor( 2 )for  740
# Found a factor( 3 )for  741
# Found a factor( 2 )for  742
# 743 is  prime
# Found a factor( 2 )for  744
# Found a factor( 5 )for  745
# Found a factor( 2 )for  746
# Found a factor( 3 )for  747
# Found a factor( 2 )for  748
# Found a factor( 7 )for  749
# Found a factor( 2 )for  750
# 751 is  prime
# Found a factor( 2 )for  752
# Found a factor( 3 )for  753
# Found a factor( 2 )for  754
# Found a factor( 5 )for  755
# Found a factor( 2 )for  756
# 757 is  prime
# Found a factor( 2 )for  758
# Found a factor( 3 )for  759
# Found a factor( 2 )for  760
# 761 is  prime
# Found a factor( 2 )for  762
# Found a factor( 7 )for  763
# Found a factor( 2 )for  764
# Found a factor( 3 )for  765
# Found a factor( 2 )for  766
# Found a factor( 13 )for  767
# Found a factor( 2 )for  768
# 769 is  prime
# Found a factor( 2 )for  770
# Found a factor( 3 )for  771
# Found a factor( 2 )for  772
# 773 is  prime
# Found a factor( 2 )for  774
# Found a factor( 5 )for  775
# Found a factor( 2 )for  776
# Found a factor( 3 )for  777
# Found a factor( 2 )for  778
# Found a factor( 19 )for  779
# Found a factor( 2 )for  780
# Found a factor( 11 )for  781
# Found a factor( 2 )for  782
# Found a factor( 3 )for  783
# Found a factor( 2 )for  784
# Found a factor( 5 )for  785
# Found a factor( 2 )for  786
# 787 is  prime
# Found a factor( 2 )for  788
# Found a factor( 3 )for  789
# Found a factor( 2 )for  790
# Found a factor( 7 )for  791
# Found a factor( 2 )for  792
# Found a factor( 13 )for  793
# Found a factor( 2 )for  794
# Found a factor( 3 )for  795
# Found a factor( 2 )for  796
# 797 is  prime
# Found a factor( 2 )for  798
# Found a factor( 17 )for  799
# Found a factor( 2 )for  800
# Found a factor( 3 )for  801
# Found a factor( 2 )for  802
# Found a factor( 11 )for  803
# Found a factor( 2 )for  804
# Found a factor( 5 )for  805
# Found a factor( 2 )for  806
# Found a factor( 3 )for  807
# Found a factor( 2 )for  808
# 809 is  prime
# Found a factor( 2 )for  810
# 811 is  prime
# Found a factor( 2 )for  812
# Found a factor( 3 )for  813
# Found a factor( 2 )for  814
# Found a factor( 5 )for  815
# Found a factor( 2 )for  816
# Found a factor( 19 )for  817
# Found a factor( 2 )for  818
# Found a factor( 3 )for  819
# Found a factor( 2 )for  820
# 821 is  prime
# Found a factor( 2 )for  822
# 823 is  prime
# Found a factor( 2 )for  824
# Found a factor( 3 )for  825
# Found a factor( 2 )for  826
# 827 is  prime
# Found a factor( 2 )for  828
# 829 is  prime
# Found a factor( 2 )for  830
# Found a factor( 3 )for  831
# Found a factor( 2 )for  832
# Found a factor( 7 )for  833
# Found a factor( 2 )for  834
# Found a factor( 5 )for  835
# Found a factor( 2 )for  836
# Found a factor( 3 )for  837
# Found a factor( 2 )for  838
# 839 is  prime
# Found a factor( 2 )for  840
# Found a factor( 29 )for  841
# Found a factor( 2 )for  842
# Found a factor( 3 )for  843
# Found a factor( 2 )for  844
# Found a factor( 5 )for  845
# Found a factor( 2 )for  846
# Found a factor( 7 )for  847
# Found a factor( 2 )for  848
# Found a factor( 3 )for  849
# Found a factor( 2 )for  850
# Found a factor( 23 )for  851
# Found a factor( 2 )for  852
# 853 is  prime
# Found a factor( 2 )for  854
# Found a factor( 3 )for  855
# Found a factor( 2 )for  856
# 857 is  prime
# Found a factor( 2 )for  858
# 859 is  prime
# Found a factor( 2 )for  860
# Found a factor( 3 )for  861
# Found a factor( 2 )for  862
# 863 is  prime
# Found a factor( 2 )for  864
# Found a factor( 5 )for  865
# Found a factor( 2 )for  866
# Found a factor( 3 )for  867
# Found a factor( 2 )for  868
# Found a factor( 11 )for  869
# Found a factor( 2 )for  870
# Found a factor( 13 )for  871
# Found a factor( 2 )for  872
# Found a factor( 3 )for  873
# Found a factor( 2 )for  874
# Found a factor( 5 )for  875
# Found a factor( 2 )for  876
# 877 is  prime
# Found a factor( 2 )for  878
# Found a factor( 3 )for  879
# Found a factor( 2 )for  880
# 881 is  prime
# Found a factor( 2 )for  882
# 883 is  prime
# Found a factor( 2 )for  884
# Found a factor( 3 )for  885
# Found a factor( 2 )for  886
# 887 is  prime
# Found a factor( 2 )for  888
# Found a factor( 7 )for  889
# Found a factor( 2 )for  890
# Found a factor( 3 )for  891
# Found a factor( 2 )for  892
# Found a factor( 19 )for  893
# Found a factor( 2 )for  894
# Found a factor( 5 )for  895
# Found a factor( 2 )for  896
# Found a factor( 3 )for  897
# Found a factor( 2 )for  898
# Found a factor( 29 )for  899
# Found a factor( 2 )for  900
# Found a factor( 17 )for  901
# Found a factor( 2 )for  902
# Found a factor( 3 )for  903
# Found a factor( 2 )for  904
# Found a factor( 5 )for  905
# Found a factor( 2 )for  906
# 907 is  prime
# Found a factor( 2 )for  908
# Found a factor( 3 )for  909
# Found a factor( 2 )for  910
# 911 is  prime
# Found a factor( 2 )for  912
# Found a factor( 11 )for  913
# Found a factor( 2 )for  914
# Found a factor( 3 )for  915
# Found a factor( 2 )for  916
# Found a factor( 7 )for  917
# Found a factor( 2 )for  918
# 919 is  prime
# Found a factor( 2 )for  920
# Found a factor( 3 )for  921
# Found a factor( 2 )for  922
# Found a factor( 13 )for  923
# Found a factor( 2 )for  924
# Found a factor( 5 )for  925
# Found a factor( 2 )for  926
# Found a factor( 3 )for  927
# Found a factor( 2 )for  928
# 929 is  prime
# Found a factor( 2 )for  930
# Found a factor( 7 )for  931
# Found a factor( 2 )for  932
# Found a factor( 3 )for  933
# Found a factor( 2 )for  934
# Found a factor( 5 )for  935
# Found a factor( 2 )for  936
# 937 is  prime
# Found a factor( 2 )for  938
# Found a factor( 3 )for  939
# Found a factor( 2 )for  940
# 941 is  prime
# Found a factor( 2 )for  942
# Found a factor( 23 )for  943
# Found a factor( 2 )for  944
# Found a factor( 3 )for  945
# Found a factor( 2 )for  946
# 947 is  prime
# Found a factor( 2 )for  948
# Found a factor( 13 )for  949
# Found a factor( 2 )for  950
# Found a factor( 3 )for  951
# Found a factor( 2 )for  952
# 953 is  prime
# Found a factor( 2 )for  954
# Found a factor( 5 )for  955
# Found a factor( 2 )for  956
# Found a factor( 3 )for  957
# Found a factor( 2 )for  958
# Found a factor( 7 )for  959
# Found a factor( 2 )for  960
# Found a factor( 31 )for  961
# Found a factor( 2 )for  962
# Found a factor( 3 )for  963
# Found a factor( 2 )for  964
# Found a factor( 5 )for  965
# Found a factor( 2 )for  966
# 967 is  prime
# Found a factor( 2 )for  968
# Found a factor( 3 )for  969
# Found a factor( 2 )for  970
# 971 is  prime
# Found a factor( 2 )for  972
# Found a factor( 7 )for  973
# Found a factor( 2 )for  974
# Found a factor( 3 )for  975
# Found a factor( 2 )for  976
# 977 is  prime
# Found a factor( 2 )for  978
# Found a factor( 11 )for  979
# Found a factor( 2 )for  980
# Found a factor( 3 )for  981
# Found a factor( 2 )for  982
# 983 is  prime
# Found a factor( 2 )for  984
# Found a factor( 5 )for  985
# Found a factor( 2 )for  986
# Found a factor( 3 )for  987
# Found a factor( 2 )for  988
# Found a factor( 23 )for  989
# Found a factor( 2 )for  990
# 991 is  prime
# Found a factor( 2 )for  992
# Found a factor( 3 )for  993
# Found a factor( 2 )for  994
# Found a factor( 5 )for  995
# Found a factor( 2 )for  996
# 997 is  prime
# Found a factor( 2 )for  998
# Found a factor( 3 )for  999
# Found a factor( 2 )for  1000
# Found a factor( 7 )for  1001
# Found a factor( 2 )for  1002
# Found a factor( 17 )for  1003
# Found a factor( 2 )for  1004
# Found a factor( 3 )for  1005
# Found a factor( 2 )for  1006
# Found a factor( 19 )for  1007
# Found a factor( 2 )for  1008
# 1009 is  prime
# Found a factor( 2 )for  1010
# Found a factor( 3 )for  1011
# Found a factor( 2 )for  1012
# 1013 is  prime
# Found a factor( 2 )for  1014
# Found a factor( 5 )for  1015
# Found a factor( 2 )for  1016
# Found a factor( 3 )for  1017
# Found a factor( 2 )for  1018
# 1019 is  prime
# Found a factor( 2 )for  1020
# 1021 is  prime
# Found a factor( 2 )for  1022
# Found a factor( 3 )for  1023
# Found a factor( 2 )for  1024
# Found a factor( 5 )for  1025
# Found a factor( 2 )for  1026
# Found a factor( 13 )for  1027
# Found a factor( 2 )for  1028
# Found a factor( 3 )for  1029
# Found a factor( 2 )for  1030
# 1031 is  prime
# Found a factor( 2 )for  1032
# 1033 is  prime
# Found a factor( 2 )for  1034
# Found a factor( 3 )for  1035
# Found a factor( 2 )for  1036
# Found a factor( 17 )for  1037
# Found a factor( 2 )for  1038
# 1039 is  prime
# Found a factor( 2 )for  1040
# Found a factor( 3 )for  1041
# Found a factor( 2 )for  1042
# Found a factor( 7 )for  1043
# Found a factor( 2 )for  1044
# Found a factor( 5 )for  1045
# Found a factor( 2 )for  1046
# Found a factor( 3 )for  1047
# Found a factor( 2 )for  1048
# 1049 is  prime
# Found a factor( 2 )for  1050
# 1051 is  prime
# Found a factor( 2 )for  1052
# Found a factor( 3 )for  1053
# Found a factor( 2 )for  1054
# Found a factor( 5 )for  1055
# Found a factor( 2 )for  1056
# Found a factor( 7 )for  1057
# Found a factor( 2 )for  1058
# Found a factor( 3 )for  1059
# Found a factor( 2 )for  1060
# 1061 is  prime
# Found a factor( 2 )for  1062
# 1063 is  prime
# Found a factor( 2 )for  1064
# Found a factor( 3 )for  1065
# Found a factor( 2 )for  1066
# Found a factor( 11 )for  1067
# Found a factor( 2 )for  1068
# 1069 is  prime
# Found a factor( 2 )for  1070
# Found a factor( 3 )for  1071
# Found a factor( 2 )for  1072
# Found a factor( 29 )for  1073
# Found a factor( 2 )for  1074
# Found a factor( 5 )for  1075
# Found a factor( 2 )for  1076
# Found a factor( 3 )for  1077
# Found a factor( 2 )for  1078
# Found a factor( 13 )for  1079
# Found a factor( 2 )for  1080
# Found a factor( 23 )for  1081
# Found a factor( 2 )for  1082
# Found a factor( 3 )for  1083
# Found a factor( 2 )for  1084
# Found a factor( 5 )for  1085
# Found a factor( 2 )for  1086
# 1087 is  prime
# Found a factor( 2 )for  1088
# Found a factor( 3 )for  1089
# Found a factor( 2 )for  1090
# 1091 is  prime
# Found a factor( 2 )for  1092
# 1093 is  prime
# Found a factor( 2 )for  1094
# Found a factor( 3 )for  1095
# Found a factor( 2 )for  1096
# 1097 is  prime
# Found a factor( 2 )for  1098
# Found a factor( 7 )for  1099
# Found a factor( 2 )for  1100
# Found a factor( 3 )for  1101
# Found a factor( 2 )for  1102
# 1103 is  prime
# Found a factor( 2 )for  1104
# Found a factor( 5 )for  1105
# Found a factor( 2 )for  1106
# Found a factor( 3 )for  1107
# Found a factor( 2 )for  1108
# 1109 is  prime
# Found a factor( 2 )for  1110
# Found a factor( 11 )for  1111
# Found a factor( 2 )for  1112
# Found a factor( 3 )for  1113
# Found a factor( 2 )for  1114
# Found a factor( 5 )for  1115
# Found a factor( 2 )for  1116
# 1117 is  prime
# Found a factor( 2 )for  1118
# Found a factor( 3 )for  1119
# Found a factor( 2 )for  1120
# Found a factor( 19 )for  1121
# Found a factor( 2 )for  1122
# 1123 is  prime
# Found a factor( 2 )for  1124
# Found a factor( 3 )for  1125
# Found a factor( 2 )for  1126
# Found a factor( 7 )for  1127
# Found a factor( 2 )for  1128
# 1129 is  prime
# Found a factor( 2 )for  1130
# Found a factor( 3 )for  1131
# Found a factor( 2 )for  1132
# Found a factor( 11 )for  1133
# Found a factor( 2 )for  1134
# Found a factor( 5 )for  1135
# Found a factor( 2 )for  1136
# Found a factor( 3 )for  1137
# Found a factor( 2 )for  1138
# Found a factor( 17 )for  1139
# Found a factor( 2 )for  1140
# Found a factor( 7 )for  1141
# Found a factor( 2 )for  1142
# Found a factor( 3 )for  1143
# Found a factor( 2 )for  1144
# Found a factor( 5 )for  1145
# Found a factor( 2 )for  1146
# Found a factor( 31 )for  1147
# Found a factor( 2 )for  1148
# Found a factor( 3 )for  1149
# Found a factor( 2 )for  1150
# 1151 is  prime
# Found a factor( 2 )for  1152
# 1153 is  prime
# Found a factor( 2 )for  1154
# Found a factor( 3 )for  1155
# Found a factor( 2 )for  1156
# Found a factor( 13 )for  1157
# Found a factor( 2 )for  1158
# Found a factor( 19 )for  1159
# Found a factor( 2 )for  1160
# Found a factor( 3 )for  1161
# Found a factor( 2 )for  1162
# 1163 is  prime
# Found a factor( 2 )for  1164
# Found a factor( 5 )for  1165
# Found a factor( 2 )for  1166
# Found a factor( 3 )for  1167
# Found a factor( 2 )for  1168
# Found a factor( 7 )for  1169
# Found a factor( 2 )for  1170
# 1171 is  prime
# Found a factor( 2 )for  1172
# Found a factor( 3 )for  1173
# Found a factor( 2 )for  1174
# Found a factor( 5 )for  1175
# Found a factor( 2 )for  1176
# Found a factor( 11 )for  1177
# Found a factor( 2 )for  1178
# Found a factor( 3 )for  1179
# Found a factor( 2 )for  1180
# 1181 is  prime
# Found a factor( 2 )for  1182
# Found a factor( 7 )for  1183
# Found a factor( 2 )for  1184
# Found a factor( 3 )for  1185
# Found a factor( 2 )for  1186
# 1187 is  prime
# Found a factor( 2 )for  1188
# Found a factor( 29 )for  1189
# Found a factor( 2 )for  1190
# Found a factor( 3 )for  1191
# Found a factor( 2 )for  1192
# 1193 is  prime
# Found a factor( 2 )for  1194
# Found a factor( 5 )for  1195
# Found a factor( 2 )for  1196
# Found a factor( 3 )for  1197
# Found a factor( 2 )for  1198
# Found a factor( 11 )for  1199
# Found a factor( 2 )for  1200
# 1201 is  prime
# Found a factor( 2 )for  1202
# Found a factor( 3 )for  1203
# Found a factor( 2 )for  1204
# Found a factor( 5 )for  1205
# Found a factor( 2 )for  1206
# Found a factor( 17 )for  1207
# Found a factor( 2 )for  1208
# Found a factor( 3 )for  1209
# Found a factor( 2 )for  1210
# Found a factor( 7 )for  1211
# Found a factor( 2 )for  1212
# 1213 is  prime
# Found a factor( 2 )for  1214
# Found a factor( 3 )for  1215
# Found a factor( 2 )for  1216
# 1217 is  prime
# Found a factor( 2 )for  1218
# Found a factor( 23 )for  1219
# Found a factor( 2 )for  1220
# Found a factor( 3 )for  1221
# Found a factor( 2 )for  1222
# 1223 is  prime
# Found a factor( 2 )for  1224
# Found a factor( 5 )for  1225
# Found a factor( 2 )for  1226
# Found a factor( 3 )for  1227
# Found a factor( 2 )for  1228
# 1229 is  prime
# Found a factor( 2 )for  1230
# 1231 is  prime
# Found a factor( 2 )for  1232
# Found a factor( 3 )for  1233
# Found a factor( 2 )for  1234
# Found a factor( 5 )for  1235
# Found a factor( 2 )for  1236
# 1237 is  prime
# Found a factor( 2 )for  1238
# Found a factor( 3 )for  1239
# Found a factor( 2 )for  1240
# Found a factor( 17 )for  1241
# Found a factor( 2 )for  1242
# Found a factor( 11 )for  1243
# Found a factor( 2 )for  1244
# Found a factor( 3 )for  1245
# Found a factor( 2 )for  1246
# Found a factor( 29 )for  1247
# Found a factor( 2 )for  1248
# 1249 is  prime
# Found a factor( 2 )for  1250
# Found a factor( 3 )for  1251
# Found a factor( 2 )for  1252
# Found a factor( 7 )for  1253
# Found a factor( 2 )for  1254
# Found a factor( 5 )for  1255
# Found a factor( 2 )for  1256
# Found a factor( 3 )for  1257
# Found a factor( 2 )for  1258
# 1259 is  prime
# Found a factor( 2 )for  1260
# Found a factor( 13 )for  1261
# Found a factor( 2 )for  1262
# Found a factor( 3 )for  1263
# Found a factor( 2 )for  1264
# Found a factor( 5 )for  1265
# Found a factor( 2 )for  1266
# Found a factor( 7 )for  1267
# Found a factor( 2 )for  1268
# Found a factor( 3 )for  1269
# Found a factor( 2 )for  1270
# Found a factor( 31 )for  1271
# Found a factor( 2 )for  1272
# Found a factor( 19 )for  1273
# Found a factor( 2 )for  1274
# Found a factor( 3 )for  1275
# Found a factor( 2 )for  1276
# 1277 is  prime
# Found a factor( 2 )for  1278
# 1279 is  prime
# Found a factor( 2 )for  1280
# Found a factor( 3 )for  1281
# Found a factor( 2 )for  1282
# 1283 is  prime
# Found a factor( 2 )for  1284
# Found a factor( 5 )for  1285
# Found a factor( 2 )for  1286
# Found a factor( 3 )for  1287
# Found a factor( 2 )for  1288
# 1289 is  prime
# Found a factor( 2 )for  1290
# 1291 is  prime
# Found a factor( 2 )for  1292
# Found a factor( 3 )for  1293
# Found a factor( 2 )for  1294
# Found a factor( 5 )for  1295
# Found a factor( 2 )for  1296
# 1297 is  prime
# Found a factor( 2 )for  1298
# Found a factor( 3 )for  1299
# Found a factor( 2 )for  1300
# 1301 is  prime
# Found a factor( 2 )for  1302
# 1303 is  prime
# Found a factor( 2 )for  1304
# Found a factor( 3 )for  1305
# Found a factor( 2 )for  1306
# 1307 is  prime
# Found a factor( 2 )for  1308
# Found a factor( 7 )for  1309
# Found a factor( 2 )for  1310
# Found a factor( 3 )for  1311
# Found a factor( 2 )for  1312
# Found a factor( 13 )for  1313
# Found a factor( 2 )for  1314
# Found a factor( 5 )for  1315
# Found a factor( 2 )for  1316
# Found a factor( 3 )for  1317
# Found a factor( 2 )for  1318
# 1319 is  prime
# Found a factor( 2 )for  1320
# 1321 is  prime
# Found a factor( 2 )for  1322
# Found a factor( 3 )for  1323
# Found a factor( 2 )for  1324
# Found a factor( 5 )for  1325
# Found a factor( 2 )for  1326
# 1327 is  prime
# Found a factor( 2 )for  1328
# Found a factor( 3 )for  1329
# Found a factor( 2 )for  1330
# Found a factor( 11 )for  1331
# Found a factor( 2 )for  1332
# Found a factor( 31 )for  1333
# Found a factor( 2 )for  1334
# Found a factor( 3 )for  1335
# Found a factor( 2 )for  1336
# Found a factor( 7 )for  1337
# Found a factor( 2 )for  1338
# Found a factor( 13 )for  1339
# Found a factor( 2 )for  1340
# Found a factor( 3 )for  1341
# Found a factor( 2 )for  1342
# Found a factor( 17 )for  1343
# Found a factor( 2 )for  1344
# Found a factor( 5 )for  1345
# Found a factor( 2 )for  1346
# Found a factor( 3 )for  1347
# Found a factor( 2 )for  1348
# Found a factor( 19 )for  1349
# Found a factor( 2 )for  1350
# Found a factor( 7 )for  1351
# Found a factor( 2 )for  1352
# Found a factor( 3 )for  1353
# Found a factor( 2 )for  1354
# Found a factor( 5 )for  1355
# Found a factor( 2 )for  1356
# Found a factor( 23 )for  1357
# Found a factor( 2 )for  1358
# Found a factor( 3 )for  1359
# Found a factor( 2 )for  1360
# 1361 is  prime
# Found a factor( 2 )for  1362
# Found a factor( 29 )for  1363
# Found a factor( 2 )for  1364
# Found a factor( 3 )for  1365
# Found a factor( 2 )for  1366
# 1367 is  prime
# Found a factor( 2 )for  1368
# Found a factor( 37 )for  1369
# Found a factor( 2 )for  1370
# Found a factor( 3 )for  1371
# Found a factor( 2 )for  1372
# 1373 is  prime
# Found a factor( 2 )for  1374
# Found a factor( 5 )for  1375
# Found a factor( 2 )for  1376
# Found a factor( 3 )for  1377
# Found a factor( 2 )for  1378
# Found a factor( 7 )for  1379
# Found a factor( 2 )for  1380
# 1381 is  prime
# Found a factor( 2 )for  1382
# Found a factor( 3 )for  1383
# Found a factor( 2 )for  1384
# Found a factor( 5 )for  1385
# Found a factor( 2 )for  1386
# Found a factor( 19 )for  1387
# Found a factor( 2 )for  1388
# Found a factor( 3 )for  1389
# Found a factor( 2 )for  1390
# Found a factor( 13 )for  1391
# Found a factor( 2 )for  1392
# Found a factor( 7 )for  1393
# Found a factor( 2 )for  1394
# Found a factor( 3 )for  1395
# Found a factor( 2 )for  1396
# Found a factor( 11 )for  1397
# Found a factor( 2 )for  1398
# 1399 is  prime
# Found a factor( 2 )for  1400
# Found a factor( 3 )for  1401
# Found a factor( 2 )for  1402
# Found a factor( 23 )for  1403
# Found a factor( 2 )for  1404
# Found a factor( 5 )for  1405
# Found a factor( 2 )for  1406
# Found a factor( 3 )for  1407
# Found a factor( 2 )for  1408
# 1409 is  prime
# Found a factor( 2 )for  1410
# Found a factor( 17 )for  1411
# Found a factor( 2 )for  1412
# Found a factor( 3 )for  1413
# Found a factor( 2 )for  1414
# Found a factor( 5 )for  1415
# Found a factor( 2 )for  1416
# Found a factor( 13 )for  1417
# Found a factor( 2 )for  1418
# Found a factor( 3 )for  1419
# Found a factor( 2 )for  1420
# Found a factor( 7 )for  1421
# Found a factor( 2 )for  1422
# 1423 is  prime
# Found a factor( 2 )for  1424
# Found a factor( 3 )for  1425
# Found a factor( 2 )for  1426
# 1427 is  prime
# Found a factor( 2 )for  1428
# 1429 is  prime
# Found a factor( 2 )for  1430
# Found a factor( 3 )for  1431
# Found a factor( 2 )for  1432
# 1433 is  prime
# Found a factor( 2 )for  1434
# Found a factor( 5 )for  1435
# Found a factor( 2 )for  1436
# Found a factor( 3 )for  1437
# Found a factor( 2 )for  1438
# 1439 is  prime
# Found a factor( 2 )for  1440
# Found a factor( 11 )for  1441
# Found a factor( 2 )for  1442
# Found a factor( 3 )for  1443
# Found a factor( 2 )for  1444
# Found a factor( 5 )for  1445
# Found a factor( 2 )for  1446
# 1447 is  prime
# Found a factor( 2 )for  1448
# Found a factor( 3 )for  1449
# Found a factor( 2 )for  1450
# 1451 is  prime
# Found a factor( 2 )for  1452
# 1453 is  prime
# Found a factor( 2 )for  1454
# Found a factor( 3 )for  1455
# Found a factor( 2 )for  1456
# Found a factor( 31 )for  1457
# Found a factor( 2 )for  1458
# 1459 is  prime
# Found a factor( 2 )for  1460
# Found a factor( 3 )for  1461
# Found a factor( 2 )for  1462
# Found a factor( 7 )for  1463
# Found a factor( 2 )for  1464
# Found a factor( 5 )for  1465
# Found a factor( 2 )for  1466
# Found a factor( 3 )for  1467
# Found a factor( 2 )for  1468
# Found a factor( 13 )for  1469
# Found a factor( 2 )for  1470
# 1471 is  prime
# Found a factor( 2 )for  1472
# Found a factor( 3 )for  1473
# Found a factor( 2 )for  1474
# Found a factor( 5 )for  1475
# Found a factor( 2 )for  1476
# Found a factor( 7 )for  1477
# Found a factor( 2 )for  1478
# Found a factor( 3 )for  1479
# Found a factor( 2 )for  1480
# 1481 is  prime
# Found a factor( 2 )for  1482
# 1483 is  prime
# Found a factor( 2 )for  1484
# Found a factor( 3 )for  1485
# Found a factor( 2 )for  1486
# 1487 is  prime
# Found a factor( 2 )for  1488
# 1489 is  prime
# Found a factor( 2 )for  1490
# Found a factor( 3 )for  1491
# Found a factor( 2 )for  1492
# 1493 is  prime
# Found a factor( 2 )for  1494
# Found a factor( 5 )for  1495
# Found a factor( 2 )for  1496
# Found a factor( 3 )for  1497
# Found a factor( 2 )for  1498
# 1499 is  prime
# Found a factor( 2 )for  1500
# Found a factor( 19 )for  1501
# Found a factor( 2 )for  1502
# Found a factor( 3 )for  1503
# Found a factor( 2 )for  1504
# Found a factor( 5 )for  1505
# Found a factor( 2 )for  1506
# Found a factor( 11 )for  1507
# Found a factor( 2 )for  1508
# Found a factor( 3 )for  1509
# Found a factor( 2 )for  1510
# 1511 is  prime
# Found a factor( 2 )for  1512
# Found a factor( 17 )for  1513
# Found a factor( 2 )for  1514
# Found a factor( 3 )for  1515
# Found a factor( 2 )for  1516
# Found a factor( 37 )for  1517
# Found a factor( 2 )for  1518
# Found a factor( 7 )for  1519
# Found a factor( 2 )for  1520
# Found a factor( 3 )for  1521
# Found a factor( 2 )for  1522
# 1523 is  prime
# Found a factor( 2 )for  1524
# Found a factor( 5 )for  1525
# Found a factor( 2 )for  1526
# Found a factor( 3 )for  1527
# Found a factor( 2 )for  1528
# Found a factor( 11 )for  1529
# Found a factor( 2 )for  1530
# 1531 is  prime
# Found a factor( 2 )for  1532
# Found a factor( 3 )for  1533
# Found a factor( 2 )for  1534
# Found a factor( 5 )for  1535
# Found a factor( 2 )for  1536
# Found a factor( 29 )for  1537
# Found a factor( 2 )for  1538
# Found a factor( 3 )for  1539
# Found a factor( 2 )for  1540
# Found a factor( 23 )for  1541
# Found a factor( 2 )for  1542
# 1543 is  prime
# Found a factor( 2 )for  1544
# Found a factor( 3 )for  1545
# Found a factor( 2 )for  1546
# Found a factor( 7 )for  1547
# Found a factor( 2 )for  1548
# 1549 is  prime
# Found a factor( 2 )for  1550
# Found a factor( 3 )for  1551
# Found a factor( 2 )for  1552
# 1553 is  prime
# Found a factor( 2 )for  1554
# Found a factor( 5 )for  1555
# Found a factor( 2 )for  1556
# Found a factor( 3 )for  1557
# Found a factor( 2 )for  1558
# 1559 is  prime
# Found a factor( 2 )for  1560
# Found a factor( 7 )for  1561
# Found a factor( 2 )for  1562
# Found a factor( 3 )for  1563
# Found a factor( 2 )for  1564
# Found a factor( 5 )for  1565
# Found a factor( 2 )for  1566
# 1567 is  prime
# Found a factor( 2 )for  1568
# Found a factor( 3 )for  1569
# Found a factor( 2 )for  1570
# 1571 is  prime
# Found a factor( 2 )for  1572
# Found a factor( 11 )for  1573
# Found a factor( 2 )for  1574
# Found a factor( 3 )for  1575
# Found a factor( 2 )for  1576
# Found a factor( 19 )for  1577
# Found a factor( 2 )for  1578
# 1579 is  prime
# Found a factor( 2 )for  1580
# Found a factor( 3 )for  1581
# Found a factor( 2 )for  1582
# 1583 is  prime
# Found a factor( 2 )for  1584
# Found a factor( 5 )for  1585
# Found a factor( 2 )for  1586
# Found a factor( 3 )for  1587
# Found a factor( 2 )for  1588
# Found a factor( 7 )for  1589
# Found a factor( 2 )for  1590
# Found a factor( 37 )for  1591
# Found a factor( 2 )for  1592
# Found a factor( 3 )for  1593
# Found a factor( 2 )for  1594
# Found a factor( 5 )for  1595
# Found a factor( 2 )for  1596
# 1597 is  prime
# Found a factor( 2 )for  1598
# Found a factor( 3 )for  1599
# Found a factor( 2 )for  1600
# 1601 is  prime
# Found a factor( 2 )for  1602
# Found a factor( 7 )for  1603
# Found a factor( 2 )for  1604
# Found a factor( 3 )for  1605
# Found a factor( 2 )for  1606
# 1607 is  prime
# Found a factor( 2 )for  1608
# 1609 is  prime
# Found a factor( 2 )for  1610
# Found a factor( 3 )for  1611
# Found a factor( 2 )for  1612
# 1613 is  prime
# Found a factor( 2 )for  1614
# Found a factor( 5 )for  1615
# Found a factor( 2 )for  1616
# Found a factor( 3 )for  1617
# Found a factor( 2 )for  1618
# 1619 is  prime
# Found a factor( 2 )for  1620
# 1621 is  prime
# Found a factor( 2 )for  1622
# Found a factor( 3 )for  1623
# Found a factor( 2 )for  1624
# Found a factor( 5 )for  1625
# Found a factor( 2 )for  1626
# 1627 is  prime
# Found a factor( 2 )for  1628
# Found a factor( 3 )for  1629
# Found a factor( 2 )for  1630
# Found a factor( 7 )for  1631
# Found a factor( 2 )for  1632
# Found a factor( 23 )for  1633
# Found a factor( 2 )for  1634
# Found a factor( 3 )for  1635
# Found a factor( 2 )for  1636
# 1637 is  prime
# Found a factor( 2 )for  1638
# Found a factor( 11 )for  1639
# Found a factor( 2 )for  1640
# Found a factor( 3 )for  1641
# Found a factor( 2 )for  1642
# Found a factor( 31 )for  1643
# Found a factor( 2 )for  1644
# Found a factor( 5 )for  1645
# Found a factor( 2 )for  1646
# Found a factor( 3 )for  1647
# Found a factor( 2 )for  1648
# Found a factor( 17 )for  1649
# Found a factor( 2 )for  1650
# Found a factor( 13 )for  1651
# Found a factor( 2 )for  1652
# Found a factor( 3 )for  1653
# Found a factor( 2 )for  1654
# Found a factor( 5 )for  1655
# Found a factor( 2 )for  1656
# 1657 is  prime
# Found a factor( 2 )for  1658
# Found a factor( 3 )for  1659
# Found a factor( 2 )for  1660
# Found a factor( 11 )for  1661
# Found a factor( 2 )for  1662
# 1663 is  prime
# Found a factor( 2 )for  1664
# Found a factor( 3 )for  1665
# Found a factor( 2 )for  1666
# 1667 is  prime
# Found a factor( 2 )for  1668
# 1669 is  prime
# Found a factor( 2 )for  1670
# Found a factor( 3 )for  1671
# Found a factor( 2 )for  1672
# Found a factor( 7 )for  1673
# Found a factor( 2 )for  1674
# Found a factor( 5 )for  1675
# Found a factor( 2 )for  1676
# Found a factor( 3 )for  1677
# Found a factor( 2 )for  1678
# Found a factor( 23 )for  1679
# Found a factor( 2 )for  1680
# Found a factor( 41 )for  1681
# Found a factor( 2 )for  1682
# Found a factor( 3 )for  1683
# Found a factor( 2 )for  1684
# Found a factor( 5 )for  1685
# Found a factor( 2 )for  1686
# Found a factor( 7 )for  1687
# Found a factor( 2 )for  1688
# Found a factor( 3 )for  1689
# Found a factor( 2 )for  1690
# Found a factor( 19 )for  1691
# Found a factor( 2 )for  1692
# 1693 is  prime
# Found a factor( 2 )for  1694
# Found a factor( 3 )for  1695
# Found a factor( 2 )for  1696
# 1697 is  prime
# Found a factor( 2 )for  1698
# 1699 is  prime
# Found a factor( 2 )for  1700
# Found a factor( 3 )for  1701
# Found a factor( 2 )for  1702
# Found a factor( 13 )for  1703
# Found a factor( 2 )for  1704
# Found a factor( 5 )for  1705
# Found a factor( 2 )for  1706
# Found a factor( 3 )for  1707
# Found a factor( 2 )for  1708
# 1709 is  prime
# Found a factor( 2 )for  1710
# Found a factor( 29 )for  1711
# Found a factor( 2 )for  1712
# Found a factor( 3 )for  1713
# Found a factor( 2 )for  1714
# Found a factor( 5 )for  1715
# Found a factor( 2 )for  1716
# Found a factor( 17 )for  1717
# Found a factor( 2 )for  1718
# Found a factor( 3 )for  1719
# Found a factor( 2 )for  1720
# 1721 is  prime
# Found a factor( 2 )for  1722
# 1723 is  prime
# Found a factor( 2 )for  1724
# Found a factor( 3 )for  1725
# Found a factor( 2 )for  1726
# Found a factor( 11 )for  1727
# Found a factor( 2 )for  1728
# Found a factor( 7 )for  1729
# Found a factor( 2 )for  1730
# Found a factor( 3 )for  1731
# Found a factor( 2 )for  1732
# 1733 is  prime
# Found a factor( 2 )for  1734
# Found a factor( 5 )for  1735
# Found a factor( 2 )for  1736
# Found a factor( 3 )for  1737
# Found a factor( 2 )for  1738
# Found a factor( 37 )for  1739
# Found a factor( 2 )for  1740
# 1741 is  prime
# Found a factor( 2 )for  1742
# Found a factor( 3 )for  1743
# Found a factor( 2 )for  1744
# Found a factor( 5 )for  1745
# Found a factor( 2 )for  1746
# 1747 is  prime
# Found a factor( 2 )for  1748
# Found a factor( 3 )for  1749
# Found a factor( 2 )for  1750
# Found a factor( 17 )for  1751
# Found a factor( 2 )for  1752
# 1753 is  prime
# Found a factor( 2 )for  1754
# Found a factor( 3 )for  1755
# Found a factor( 2 )for  1756
# Found a factor( 7 )for  1757
# Found a factor( 2 )for  1758
# 1759 is  prime
# Found a factor( 2 )for  1760
# Found a factor( 3 )for  1761
# Found a factor( 2 )for  1762
# Found a factor( 41 )for  1763
# Found a factor( 2 )for  1764
# Found a factor( 5 )for  1765
# Found a factor( 2 )for  1766
# Found a factor( 3 )for  1767
# Found a factor( 2 )for  1768
# Found a factor( 29 )for  1769
# Found a factor( 2 )for  1770
# Found a factor( 7 )for  1771
# Found a factor( 2 )for  1772
# Found a factor( 3 )for  1773
# Found a factor( 2 )for  1774
# Found a factor( 5 )for  1775
# Found a factor( 2 )for  1776
# 1777 is  prime
# Found a factor( 2 )for  1778
# Found a factor( 3 )for  1779
# Found a factor( 2 )for  1780
# Found a factor( 13 )for  1781
# Found a factor( 2 )for  1782
# 1783 is  prime
# Found a factor( 2 )for  1784
# Found a factor( 3 )for  1785
# Found a factor( 2 )for  1786
# 1787 is  prime
# Found a factor( 2 )for  1788
# 1789 is  prime
# Found a factor( 2 )for  1790
# Found a factor( 3 )for  1791
# Found a factor( 2 )for  1792
# Found a factor( 11 )for  1793
# Found a factor( 2 )for  1794
# Found a factor( 5 )for  1795
# Found a factor( 2 )for  1796
# Found a factor( 3 )for  1797
# Found a factor( 2 )for  1798
# Found a factor( 7 )for  1799
# Found a factor( 2 )for  1800
# 1801 is  prime
# Found a factor( 2 )for  1802
# Found a factor( 3 )for  1803
# Found a factor( 2 )for  1804
# Found a factor( 5 )for  1805
# Found a factor( 2 )for  1806
# Found a factor( 13 )for  1807
# Found a factor( 2 )for  1808
# Found a factor( 3 )for  1809
# Found a factor( 2 )for  1810
# 1811 is  prime
# Found a factor( 2 )for  1812
# Found a factor( 7 )for  1813
# Found a factor( 2 )for  1814
# Found a factor( 3 )for  1815
# Found a factor( 2 )for  1816
# Found a factor( 23 )for  1817
# Found a factor( 2 )for  1818
# Found a factor( 17 )for  1819
# Found a factor( 2 )for  1820
# Found a factor( 3 )for  1821
# Found a factor( 2 )for  1822
# 1823 is  prime
# Found a factor( 2 )for  1824
# ...
# Found a factor( 2 )for  9420
# 9421 is  prime
# Found a factor( 2 )for  9422
# Found a factor( 3 )for  9423
# Found a factor( 2 )for  9424
# Found a factor( 5 )for  9425
# Found a factor( 2 )for  9426
# Found a factor( 11 )for  9427
# Found a factor( 2 )for  9428
# Found a factor( 3 )for  9429
# Found a factor( 2 )for  9430
# 9431 is  prime
# Found a factor( 2 )for  9432
# 9433 is  prime
# Found a factor( 2 )for  9434
# Found a factor( 3 )for  9435
# Found a factor( 2 )for  9436
# 9437 is  prime
# Found a factor( 2 )for  9438
# 9439 is  prime
# Found a factor( 2 )for  9440
# Found a factor( 3 )for  9441
# Found a factor( 2 )for  9442
# Found a factor( 7 )for  9443
# Found a factor( 2 )for  9444
# Found a factor( 5 )for  9445
# Found a factor( 2 )for  9446
# Found a factor( 3 )for  9447
# Found a factor( 2 )for  9448
# Found a factor( 11 )for  9449
# Found a factor( 2 )for  9450
# Found a factor( 13 )for  9451
# Found a factor( 2 )for  9452
# Found a factor( 3 )for  9453
# Found a factor( 2 )for  9454
# Found a factor( 5 )for  9455
# Found a factor( 2 )for  9456
# Found a factor( 7 )for  9457
# Found a factor( 2 )for  9458
# Found a factor( 3 )for  9459
# Found a factor( 2 )for  9460
# 9461 is  prime
# Found a factor( 2 )for  9462
# 9463 is  prime
# Found a factor( 2 )for  9464
# Found a factor( 3 )for  9465
# Found a factor( 2 )for  9466
# 9467 is  prime
# Found a factor( 2 )for  9468
# Found a factor( 17 )for  9469
# Found a factor( 2 )for  9470
# Found a factor( 3 )for  9471
# Found a factor( 2 )for  9472
# 9473 is  prime
# Found a factor( 2 )for  9474
# Found a factor( 5 )for  9475
# Found a factor( 2 )for  9476
# Found a factor( 3 )for  9477
# Found a factor( 2 )for  9478
# 9479 is  prime
# Found a factor( 2 )for  9480
# Found a factor( 19 )for  9481
# Found a factor( 2 )for  9482
# Found a factor( 3 )for  9483
# Found a factor( 2 )for  9484
# Found a factor( 5 )for  9485
# Found a factor( 2 )for  9486
# Found a factor( 53 )for  9487
# Found a factor( 2 )for  9488
# Found a factor( 3 )for  9489
# Found a factor( 2 )for  9490
# 9491 is  prime
# Found a factor( 2 )for  9492
# Found a factor( 11 )for  9493
# Found a factor( 2 )for  9494
# Found a factor( 3 )for  9495
# Found a factor( 2 )for  9496
# 9497 is  prime
# Found a factor( 2 )for  9498
# Found a factor( 7 )for  9499
# Found a factor( 2 )for  9500
# Found a factor( 3 )for  9501
# Found a factor( 2 )for  9502
# Found a factor( 13 )for  9503
# Found a factor( 2 )for  9504
# Found a factor( 5 )for  9505
# Found a factor( 2 )for  9506
# Found a factor( 3 )for  9507
# Found a factor( 2 )for  9508
# Found a factor( 37 )for  9509
# Found a factor( 2 )for  9510
# 9511 is  prime
# Found a factor( 2 )for  9512
# Found a factor( 3 )for  9513
# Found a factor( 2 )for  9514
# Found a factor( 5 )for  9515
# Found a factor( 2 )for  9516
# Found a factor( 31 )for  9517
# Found a factor( 2 )for  9518
# Found a factor( 3 )for  9519
# Found a factor( 2 )for  9520
# 9521 is  prime
# Found a factor( 2 )for  9522
# Found a factor( 89 )for  9523
# Found a factor( 2 )for  9524
# Found a factor( 3 )for  9525
# Found a factor( 2 )for  9526
# Found a factor( 7 )for  9527
# Found a factor( 2 )for  9528
# Found a factor( 13 )for  9529
# Found a factor( 2 )for  9530
# Found a factor( 3 )for  9531
# Found a factor( 2 )for  9532
# 9533 is  prime
# Found a factor( 2 )for  9534
# Found a factor( 5 )for  9535
# Found a factor( 2 )for  9536
# Found a factor( 3 )for  9537
# Found a factor( 2 )for  9538
# 9539 is  prime
# Found a factor( 2 )for  9540
# Found a factor( 7 )for  9541
# Found a factor( 2 )for  9542
# Found a factor( 3 )for  9543
# Found a factor( 2 )for  9544
# Found a factor( 5 )for  9545
# Found a factor( 2 )for  9546
# 9547 is  prime
# Found a factor( 2 )for  9548
# Found a factor( 3 )for  9549
# Found a factor( 2 )for  9550
# 9551 is  prime
# Found a factor( 2 )for  9552
# Found a factor( 41 )for  9553
# Found a factor( 2 )for  9554
# Found a factor( 3 )for  9555
# Found a factor( 2 )for  9556
# Found a factor( 19 )for  9557
# Found a factor( 2 )for  9558
# Found a factor( 11 )for  9559
# Found a factor( 2 )for  9560
# Found a factor( 3 )for  9561
# Found a factor( 2 )for  9562
# Found a factor( 73 )for  9563
# Found a factor( 2 )for  9564
# Found a factor( 5 )for  9565
# Found a factor( 2 )for  9566
# Found a factor( 3 )for  9567
# Found a factor( 2 )for  9568
# Found a factor( 7 )for  9569
# Found a factor( 2 )for  9570
# Found a factor( 17 )for  9571
# Found a factor( 2 )for  9572
# Found a factor( 3 )for  9573
# Found a factor( 2 )for  9574
# Found a factor( 5 )for  9575
# Found a factor( 2 )for  9576
# Found a factor( 61 )for  9577
# Found a factor( 2 )for  9578
# Found a factor( 3 )for  9579
# Found a factor( 2 )for  9580
# Found a factor( 11 )for  9581
# Found a factor( 2 )for  9582
# Found a factor( 7 )for  9583
# Found a factor( 2 )for  9584
# Found a factor( 3 )for  9585
# Found a factor( 2 )for  9586
# 9587 is  prime
# Found a factor( 2 )for  9588
# Found a factor( 43 )for  9589
# Found a factor( 2 )for  9590
# Found a factor( 3 )for  9591
# Found a factor( 2 )for  9592
# Found a factor( 53 )for  9593
# Found a factor( 2 )for  9594
# Found a factor( 5 )for  9595
# Found a factor( 2 )for  9596
# Found a factor( 3 )for  9597
# Found a factor( 2 )for  9598
# Found a factor( 29 )for  9599
# Found a factor( 2 )for  9600
# 9601 is  prime
# Found a factor( 2 )for  9602
# Found a factor( 3 )for  9603
# Found a factor( 2 )for  9604
# Found a factor( 5 )for  9605
# Found a factor( 2 )for  9606
# Found a factor( 13 )for  9607
# Found a factor( 2 )for  9608
# Found a factor( 3 )for  9609
# Found a factor( 2 )for  9610
# Found a factor( 7 )for  9611
# Found a factor( 2 )for  9612
# 9613 is  prime
# Found a factor( 2 )for  9614
# Found a factor( 3 )for  9615
# Found a factor( 2 )for  9616
# Found a factor( 59 )for  9617
# Found a factor( 2 )for  9618
# 9619 is  prime
# Found a factor( 2 )for  9620
# Found a factor( 3 )for  9621
# Found a factor( 2 )for  9622
# 9623 is  prime
# Found a factor( 2 )for  9624
# Found a factor( 5 )for  9625
# Found a factor( 2 )for  9626
# Found a factor( 3 )for  9627
# Found a factor( 2 )for  9628
# 9629 is  prime
# Found a factor( 2 )for  9630
# 9631 is  prime
# Found a factor( 2 )for  9632
# Found a factor( 3 )for  9633
# Found a factor( 2 )for  9634
# Found a factor( 5 )for  9635
# Found a factor( 2 )for  9636
# Found a factor( 23 )for  9637
# Found a factor( 2 )for  9638
# Found a factor( 3 )for  9639
# Found a factor( 2 )for  9640
# Found a factor( 31 )for  9641
# Found a factor( 2 )for  9642
# 9643 is  prime
# Found a factor( 2 )for  9644
# Found a factor( 3 )for  9645
# Found a factor( 2 )for  9646
# Found a factor( 11 )for  9647
# Found a factor( 2 )for  9648
# 9649 is  prime
# Found a factor( 2 )for  9650
# Found a factor( 3 )for  9651
# Found a factor( 2 )for  9652
# Found a factor( 7 )for  9653
# Found a factor( 2 )for  9654
# Found a factor( 5 )for  9655
# Found a factor( 2 )for  9656
# Found a factor( 3 )for  9657
# Found a factor( 2 )for  9658
# Found a factor( 13 )for  9659
# Found a factor( 2 )for  9660
# 9661 is  prime
# Found a factor( 2 )for  9662
# Found a factor( 3 )for  9663
# Found a factor( 2 )for  9664
# Found a factor( 5 )for  9665
# Found a factor( 2 )for  9666
# Found a factor( 7 )for  9667
# Found a factor( 2 )for  9668
# Found a factor( 3 )for  9669
# Found a factor( 2 )for  9670
# Found a factor( 19 )for  9671
# Found a factor( 2 )for  9672
# Found a factor( 17 )for  9673
# Found a factor( 2 )for  9674
# Found a factor( 3 )for  9675
# Found a factor( 2 )for  9676
# 9677 is  prime
# Found a factor( 2 )for  9678
# 9679 is  prime
# Found a factor( 2 )for  9680
# Found a factor( 3 )for  9681
# Found a factor( 2 )for  9682
# Found a factor( 23 )for  9683
# Found a factor( 2 )for  9684
# Found a factor( 5 )for  9685
# Found a factor( 2 )for  9686
# Found a factor( 3 )for  9687
# Found a factor( 2 )for  9688
# 9689 is  prime
# Found a factor( 2 )for  9690
# Found a factor( 11 )for  9691
# Found a factor( 2 )for  9692
# Found a factor( 3 )for  9693
# Found a factor( 2 )for  9694
# Found a factor( 5 )for  9695
# Found a factor( 2 )for  9696
# 9697 is  prime
# Found a factor( 2 )for  9698
# Found a factor( 3 )for  9699
# Found a factor( 2 )for  9700
# Found a factor( 89 )for  9701
# Found a factor( 2 )for  9702
# Found a factor( 31 )for  9703
# Found a factor( 2 )for  9704
# Found a factor( 3 )for  9705
# Found a factor( 2 )for  9706
# Found a factor( 17 )for  9707
# Found a factor( 2 )for  9708
# Found a factor( 7 )for  9709
# Found a factor( 2 )for  9710
# Found a factor( 3 )for  9711
# Found a factor( 2 )for  9712
# Found a factor( 11 )for  9713
# Found a factor( 2 )for  9714
# Found a factor( 5 )for  9715
# Found a factor( 2 )for  9716
# Found a factor( 3 )for  9717
# Found a factor( 2 )for  9718
# 9719 is  prime
# Found a factor( 2 )for  9720
# 9721 is  prime
# Found a factor( 2 )for  9722
# Found a factor( 3 )for  9723
# Found a factor( 2 )for  9724
# Found a factor( 5 )for  9725
# Found a factor( 2 )for  9726
# Found a factor( 71 )for  9727
# Found a factor( 2 )for  9728
# Found a factor( 3 )for  9729
# Found a factor( 2 )for  9730
# Found a factor( 37 )for  9731
# Found a factor( 2 )for  9732
# 9733 is  prime
# Found a factor( 2 )for  9734
# Found a factor( 3 )for  9735
# Found a factor( 2 )for  9736
# Found a factor( 7 )for  9737
# Found a factor( 2 )for  9738
# 9739 is  prime
# Found a factor( 2 )for  9740
# Found a factor( 3 )for  9741
# Found a factor( 2 )for  9742
# 9743 is  prime
# Found a factor( 2 )for  9744
# Found a factor( 5 )for  9745
# Found a factor( 2 )for  9746
# Found a factor( 3 )for  9747
# Found a factor( 2 )for  9748
# 9749 is  prime
# Found a factor( 2 )for  9750
# Found a factor( 7 )for  9751
# Found a factor( 2 )for  9752
# Found a factor( 3 )for  9753
# Found a factor( 2 )for  9754
# Found a factor( 5 )for  9755
# Found a factor( 2 )for  9756
# Found a factor( 11 )for  9757
# Found a factor( 2 )for  9758
# Found a factor( 3 )for  9759
# Found a factor( 2 )for  9760
# Found a factor( 43 )for  9761
# Found a factor( 2 )for  9762
# Found a factor( 13 )for  9763
# Found a factor( 2 )for  9764
# Found a factor( 3 )for  9765
# Found a factor( 2 )for  9766
# 9767 is  prime
# Found a factor( 2 )for  9768
# 9769 is  prime
# Found a factor( 2 )for  9770
# Found a factor( 3 )for  9771
# Found a factor( 2 )for  9772
# Found a factor( 29 )for  9773
# Found a factor( 2 )for  9774
# Found a factor( 5 )for  9775
# Found a factor( 2 )for  9776
# Found a factor( 3 )for  9777
# Found a factor( 2 )for  9778
# Found a factor( 7 )for  9779
# Found a factor( 2 )for  9780
# 9781 is  prime
# Found a factor( 2 )for  9782
# Found a factor( 3 )for  9783
# Found a factor( 2 )for  9784
# Found a factor( 5 )for  9785
# Found a factor( 2 )for  9786
# 9787 is  prime
# Found a factor( 2 )for  9788
# Found a factor( 3 )for  9789
# Found a factor( 2 )for  9790
# 9791 is  prime
# Found a factor( 2 )for  9792
# Found a factor( 7 )for  9793
# Found a factor( 2 )for  9794
# Found a factor( 3 )for  9795
# Found a factor( 2 )for  9796
# Found a factor( 97 )for  9797
# Found a factor( 2 )for  9798
# Found a factor( 41 )for  9799
# Found a factor( 2 )for  9800
# Found a factor( 3 )for  9801
# Found a factor( 2 )for  9802
# 9803 is  prime
# Found a factor( 2 )for  9804
# Found a factor( 5 )for  9805
# Found a factor( 2 )for  9806
# Found a factor( 3 )for  9807
# Found a factor( 2 )for  9808
# Found a factor( 17 )for  9809
# Found a factor( 2 )for  9810
# 9811 is  prime
# Found a factor( 2 )for  9812
# Found a factor( 3 )for  9813
# Found a factor( 2 )for  9814
# Found a factor( 5 )for  9815
# Found a factor( 2 )for  9816
# 9817 is  prime
# Found a factor( 2 )for  9818
# Found a factor( 3 )for  9819
# Found a factor( 2 )for  9820
# Found a factor( 7 )for  9821
# Found a factor( 2 )for  9822
# Found a factor( 11 )for  9823
# Found a factor( 2 )for  9824
# Found a factor( 3 )for  9825
# Found a factor( 2 )for  9826
# Found a factor( 31 )for  9827
# Found a factor( 2 )for  9828
# 9829 is  prime
# Found a factor( 2 )for  9830
# Found a factor( 3 )for  9831
# Found a factor( 2 )for  9832
# 9833 is  prime
# Found a factor( 2 )for  9834
# Found a factor( 5 )for  9835
# Found a factor( 2 )for  9836
# Found a factor( 3 )for  9837
# Found a factor( 2 )for  9838
# 9839 is  prime
# Found a factor( 2 )for  9840
# Found a factor( 13 )for  9841
# Found a factor( 2 )for  9842
# Found a factor( 3 )for  9843
# Found a factor( 2 )for  9844
# Found a factor( 5 )for  9845
# Found a factor( 2 )for  9846
# Found a factor( 43 )for  9847
# Found a factor( 2 )for  9848
# Found a factor( 3 )for  9849
# Found a factor( 2 )for  9850
# 9851 is  prime
# Found a factor( 2 )for  9852
# Found a factor( 59 )for  9853
# Found a factor( 2 )for  9854
# Found a factor( 3 )for  9855
# Found a factor( 2 )for  9856
# 9857 is  prime
# Found a factor( 2 )for  9858
# 9859 is  prime
# Found a factor( 2 )for  9860
# Found a factor( 3 )for  9861
# Found a factor( 2 )for  9862
# Found a factor( 7 )for  9863
# Found a factor( 2 )for  9864
# Found a factor( 5 )for  9865
# Found a factor( 2 )for  9866
# Found a factor( 3 )for  9867
# Found a factor( 2 )for  9868
# Found a factor( 71 )for  9869
# Found a factor( 2 )for  9870
# 9871 is  prime
# Found a factor( 2 )for  9872
# Found a factor( 3 )for  9873
# Found a factor( 2 )for  9874
# Found a factor( 5 )for  9875
# Found a factor( 2 )for  9876
# Found a factor( 7 )for  9877
# Found a factor( 2 )for  9878
# Found a factor( 3 )for  9879
# Found a factor( 2 )for  9880
# Found a factor( 41 )for  9881
# Found a factor( 2 )for  9882
# 9883 is  prime
# Found a factor( 2 )for  9884
# Found a factor( 3 )for  9885
# Found a factor( 2 )for  9886
# 9887 is  prime
# Found a factor( 2 )for  9888
# Found a factor( 11 )for  9889
# Found a factor( 2 )for  9890
# Found a factor( 3 )for  9891
# Found a factor( 2 )for  9892
# Found a factor( 13 )for  9893
# Found a factor( 2 )for  9894
# Found a factor( 5 )for  9895
# Found a factor( 2 )for  9896
# Found a factor( 3 )for  9897
# Found a factor( 2 )for  9898
# Found a factor( 19 )for  9899
# Found a factor( 2 )for  9900
# 9901 is  prime
# Found a factor( 2 )for  9902
# Found a factor( 3 )for  9903
# Found a factor( 2 )for  9904
# Found a factor( 5 )for  9905
# Found a factor( 2 )for  9906
# 9907 is  prime
# Found a factor( 2 )for  9908
# Found a factor( 3 )for  9909
# Found a factor( 2 )for  9910
# Found a factor( 11 )for  9911
# Found a factor( 2 )for  9912
# Found a factor( 23 )for  9913
# Found a factor( 2 )for  9914
# Found a factor( 3 )for  9915
# Found a factor( 2 )for  9916
# Found a factor( 47 )for  9917
# Found a factor( 2 )for  9918
# Found a factor( 7 )for  9919
# Found a factor( 2 )for  9920
# Found a factor( 3 )for  9921
# Found a factor( 2 )for  9922
# 9923 is  prime
# Found a factor( 2 )for  9924
# Found a factor( 5 )for  9925
# Found a factor( 2 )for  9926
# Found a factor( 3 )for  9927
# Found a factor( 2 )for  9928
# 9929 is  prime
# Found a factor( 2 )for  9930
# 9931 is  prime
# Found a factor( 2 )for  9932
# Found a factor( 3 )for  9933
# Found a factor( 2 )for  9934
# Found a factor( 5 )for  9935
# Found a factor( 2 )for  9936
# Found a factor( 19 )for  9937
# Found a factor( 2 )for  9938
# Found a factor( 3 )for  9939
# Found a factor( 2 )for  9940
# 9941 is  prime
# Found a factor( 2 )for  9942
# Found a factor( 61 )for  9943
# Found a factor( 2 )for  9944
# Found a factor( 3 )for  9945
# Found a factor( 2 )for  9946
# Found a factor( 7 )for  9947
# Found a factor( 2 )for  9948
# 9949 is  prime
# Found a factor( 2 )for  9950
# Found a factor( 3 )for  9951
# Found a factor( 2 )for  9952
# Found a factor( 37 )for  9953
# Found a factor( 2 )for  9954
# Found a factor( 5 )for  9955
# Found a factor( 2 )for  9956
# Found a factor( 3 )for  9957
# Found a factor( 2 )for  9958
# Found a factor( 23 )for  9959
# Found a factor( 2 )for  9960
# Found a factor( 7 )for  9961
# Found a factor( 2 )for  9962
# Found a factor( 3 )for  9963
# Found a factor( 2 )for  9964
# Found a factor( 5 )for  9965
# Found a factor( 2 )for  9966
# 9967 is  prime
# Found a factor( 2 )for  9968
# Found a factor( 3 )for  9969
# Found a factor( 2 )for  9970
# Found a factor( 13 )for  9971
# Found a factor( 2 )for  9972
# 9973 is  prime
# Found a factor( 2 )for  9974
# Found a factor( 3 )for  9975
# Found a factor( 2 )for  9976
# Found a factor( 11 )for  9977
# Found a factor( 2 )for  9978
# Found a factor( 17 )for  9979
# Found a factor( 2 )for  9980
# Found a factor( 3 )for  9981
# Found a factor( 2 )for  9982
# Found a factor( 67 )for  9983
# Found a factor( 2 )for  9984
# Found a factor( 5 )for  9985
# Found a factor( 2 )for  9986
# Found a factor( 3 )for  9987
# Found a factor( 2 )for  9988
# Found a factor( 7 )for  9989
# Found a factor( 2 )for  9990
# Found a factor( 97 )for  9991
# Found a factor( 2 )for  9992
# Found a factor( 3 )for  9993
# Found a factor( 2 )for  9994
# Found a factor( 5 )for  9995
# Found a factor( 2 )for  9996
# Found a factor( 13 )for  9997
# Found a factor( 2 )for  9998
# Found a factor( 3 )for  9999
